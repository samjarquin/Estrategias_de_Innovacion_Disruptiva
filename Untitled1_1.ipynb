# %%
import pandas as pd

ch = pd.read_csv('california_housing_test.csv')
ch.head() # va a mostrar la tabla con los primeros 5 renglone
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
ch.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
ch_1 = ch[["total_rooms", "population", "median_income", "median_house_value"]]
ch_1["median_income"]
# Out:
# 0       6.6085
# 1       3.5990
# 2       5.7934
# 3       6.1359
# 4       2.9375
#          ...
# 2995    1.1790
# 2996    3.3906
# 2997    2.2895
# 2998    3.2708
# 2999    8.5608
# Name: median_income, Length: 3000, dtype: float64

# %% [markdown]
# ## Visualización de datos

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ch_1
# Out:
#       total_rooms  population  median_income  median_house_value
# 0          3885.0      1537.0         6.6085            344700.0
# 1          1510.0       809.0         3.5990            176500.0
# 2          3589.0      1484.0         5.7934            270500.0
# 3            67.0        49.0         6.1359            330000.0
# 4          1241.0       850.0         2.9375             81700.0
# ...           ...         ...            ...                 ...
# 2995       1450.0      1258.0         1.1790            225000.0
# 2996       5257.0      3496.0         3.3906            237200.0
# 2997        956.0       693.0         2.2895             62000.0
# 2998         96.0        46.0         3.2708            162500.0
# 2999       1765.0       753.0         8.5608            500001.0
#
# [3000 rows x 4 columns]

# %%
ch_1[ch_1["median_house_value"]<= 30000.0]
# Out:
#       total_rooms  population  median_income  median_house_value
# 2001        845.0      1230.0         1.0918             22500.0

# %%
ch_1_filtered.describe()
# Out:
#        total_rooms   population  median_income  median_house_value
# count    23.000000    23.000000      23.000000           23.000000
# mean   1636.000000  1160.521739       1.894926        44591.304348
# std    1691.482781   968.082165       0.672003         3435.498249
# min     120.000000   140.000000       0.825200        37500.000000
# 25%     948.500000   526.000000       1.467500        42600.000000
# 50%    1343.000000  1063.000000       1.710900        44800.000000
# 75%    1800.500000  1517.000000       2.189750        47500.000000
# max    8739.000000  4781.000000       3.687500        49800.000000

# %%
ch_1_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 51 to 2779
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   total_rooms         23 non-null     float64
#  1   population          23 non-null     float64
#  2   median_income       23 non-null     float64
#  3   median_house_value  23 non-null     float64
# dtypes: float64(4)
# memory usage: 920.0 bytes

# %%
ch_1_filtered.iloc[5]
# Out:
# total_rooms            1184.0000
# population              672.0000
# median_income             1.9107
# median_house_value    39800.0000
# Name: 734, dtype: float64

# %%
ch_1_filtered = ch_1_filtered.reset_index(drop=True)
display(ch_1_filtered)
# Out:
#     total_rooms  population  median_income  median_house_value
# 0         554.0       426.0         2.3516             47500.0
# 1        2053.0      1193.0         1.4923             44400.0
# 2         674.0       575.0         2.2024             45000.0
# 3        1382.0      1469.0         1.3967             46500.0
# 4        2279.0      1908.0         1.3952             43100.0
# 5        1184.0       672.0         1.9107             39800.0
# 6         972.0      1134.0         1.6300             49500.0
# 7        1495.0       858.0         2.9306             46300.0
# 8        1838.0      1628.0         1.6452             41500.0
# 9        2009.0      2219.0         1.2101             49100.0
# 10       2943.0      1565.0         2.5313             45800.0
# 11       1343.0      1063.0         1.7500             49800.0
# 12        365.0       140.0         1.7969             37500.0
# 13       1377.0      1280.0         1.2344             43300.0
# ...

# %%
ch_1_filtered.iloc[18]
# Out:
# total_rooms            1236.0000
# population              413.0000
# median_income             3.6875
# median_house_value    40000.0000
# Name: 18, dtype: float64
